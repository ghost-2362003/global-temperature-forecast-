# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
import warnings
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error as mse

# %%
data = pd.read_csv('globalWarming.csv')
data.drop('Unnamed: 0', axis = 1, inplace = True)
data.head()
# Out:
#    date  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0  1850                7.900667                           0.876417
# 1  1851                8.178583                           0.881917
# 2  1852                8.100167                           0.918250
# 3  1853                8.041833                           0.835000
# 4  1854                8.210500                           0.825667
#
#    LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0           13.476667                       2.394833            1.964333
# 1           13.081000                       2.397250            2.203917
# 2           13.397333                       2.619250            2.337000
# 3           13.886583                       2.095083            1.892500
# 4           13.977417                       1.783333            1.762167
#
#    LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# 0                       1.571167                       14.867167
# 1                       1.632417                       14.991833
# 2                       1.382917                       15.006500
# 3                       1.355583                       14.955167
# 4                       1.357000                       14.991000
#
#    LandAndOceanAverageTemperatureUncertainty
# 0                                   0.308167
# 1                                   0.312083
# 2                                   0.316417
# 3                                   0.283833
# 4                                   0.276417

# %%
data = data[[c for c in data if c != "LandAverageTemperature"] + ["LandAverageTemperature"]]
data.head()
# Out:
#    date  LandAverageTemperatureUncertainty  LandMaxTemperature  \
# 0  1850                           0.876417           13.476667
# 1  1851                           0.881917           13.081000
# 2  1852                           0.918250           13.397333
# 3  1853                           0.835000           13.886583
# 4  1854                           0.825667           13.977417
#
#    LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0                       2.394833            1.964333
# 1                       2.397250            2.203917
# 2                       2.619250            2.337000
# 3                       2.095083            1.892500
# 4                       1.783333            1.762167
#
#    LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# 0                       1.571167                       14.867167
# 1                       1.632417                       14.991833
# 2                       1.382917                       15.006500
# 3                       1.355583                       14.955167
# 4                       1.357000                       14.991000
#
#    LandAndOceanAverageTemperatureUncertainty  LandAverageTemperature
# 0                                   0.308167                7.900667
# 1                                   0.312083                8.178583
# 2                                   0.316417                8.100167
# 3                                   0.283833                8.041833
# 4                                   0.276417                8.210500

# %%
data = data[['date','LandAverageTemperatureUncertainty'] + ['LandAndOceanAverageTemperature'] + [c for c in data if c not in ['date','LandAverageTemperatureUncertainty','LandAndOceanAverageTemperature']]]
data.head()
# Out:
#    date  LandAverageTemperatureUncertainty  LandAndOceanAverageTemperature  \
# 0  1850                           0.876417                       14.867167
# 1  1851                           0.881917                       14.991833
# 2  1852                           0.918250                       15.006500
# 3  1853                           0.835000                       14.955167
# 4  1854                           0.825667                       14.991000
#
#    LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0           13.476667                       2.394833            1.964333
# 1           13.081000                       2.397250            2.203917
# 2           13.397333                       2.619250            2.337000
# 3           13.886583                       2.095083            1.892500
# 4           13.977417                       1.783333            1.762167
#
#    LandMinTemperatureUncertainty  LandAndOceanAverageTemperatureUncertainty  \
# 0                       1.571167                                   0.308167
# 1                       1.632417                                   0.312083
# 2                       1.382917                                   0.316417
# 3                       1.355583                                   0.283833
# 4                       1.357000                                   0.276417
#
#    LandAverageTemperature
# 0                7.900667
# 1                8.178583
# 2                8.100167
# 3                8.041833
# 4                8.210500

# %%
X = data.iloc[:, 1:3]
y = data.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 1)
X.head()
# Out:
#    LandAverageTemperatureUncertainty  LandAndOceanAverageTemperature
# 0                           0.876417                       14.867167
# 1                           0.881917                       14.991833
# 2                           0.918250                       15.006500
# 3                           0.835000                       14.955167
# 4                           0.825667                       14.991000

# %%
warnings.filterwarnings('ignore')
lreg = LinearRegression()
sfs1 = sfs(lreg, k_features=2, forward=True, verbose=2, scoring='neg_mean_squared_error')
sfs1 = sfs1.fit(X, y)
# Out:
# [2024-06-25 21:28:30] Features: 1/2 -- score: -0.017429347213889664
# [2024-06-25 21:28:30] Features: 2/2 -- score: -0.02042768684169417

# %%
feat_names = list(sfs1.k_feature_names_)
print(feat_names)
# Out:
# ['LandAverageTemperatureUncertainty', 'LandAndOceanAverageTemperature']

# %%
std_scaler = StandardScaler()
std_scaler.fit(X_train, y_train)
linear = LinearRegression()
linear.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
pred = linear.predict(X_test)
rmse(pred, y_test)
# Out:
# 0.11901071427286568

# %% [markdown]
# creating a function to get the best combination of random state for the linear model

# %%
def best_random_state(r_state, ratio):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = ratio, random_state = r_state)
    model = LinearRegression()
    model.fit(X_train, y_train)
    pred = model.predict(X_test)
    return mse(y_test, pred)

# %%
random_state = 0
test_size = 0
error = 1
for state in range(2, 20):
    for ratio in range(10, 30, 2):
        test_error = best_random_state(state, ratio/100)
        print(f'{test_error} for random_state = {state} and test_size = {ratio/100}')
        if(error>test_error):
            error = test_error
            random_state = state
            test_size = ratio/100
print('\n')
print(f'least error is {error} for random_state = {random_state} and test_size = {test_size}')
# Out:
# 0.01057506782690608 for random_state = 2 and test_size = 0.1
# 0.010469225761268866 for random_state = 2 and test_size = 0.12
# 0.01238449109517239 for random_state = 2 and test_size = 0.14
# 0.013751905101062079 for random_state = 2 and test_size = 0.16
# 0.013399772463855946 for random_state = 2 and test_size = 0.18
# 0.013476967609080473 for random_state = 2 and test_size = 0.2
# 0.01589958145773952 for random_state = 2 and test_size = 0.22
# 0.015094505398085179 for random_state = 2 and test_size = 0.24
# 0.014602486462800067 for random_state = 2 and test_size = 0.26
# 0.013783532189719524 for random_state = 2 and test_size = 0.28
# 0.013299376767318785 for random_state = 3 and test_size = 0.1
# 0.015663423564086534 for random_state = 3 and test_size = 0.12
# 0.015536424180005183 for random_state = 3 and test_size = 0.14
# 0.015012699529930814 for random_state = 3 and test_size = 0.16
# 0.014769446986145298 for random_state = 3 and test_size = 0.18
# 0.013971492254057869 for random_state = 3 and test_size = 0.2
# 0.0167644193235701 for random_state = 3 and test_size = 0.22
# 0.01766487569071725 for random_state = 3 and test_size = 0.24
# 0.01687590428342618 for random_state = 3 and test_size = 0.26
# 0.016247688672320102 for random_state = 3 and test_size = 0.28
# 0.015608446798863931 for random_state = 4 and test_size = 0.1
# 0.01763865544515146 for random_state = 4 and test_size = 0.12
# 0.016095550286646054 for random_state = 4 and test_size = 0.14
# 0.017361092567466846 for random_state = 4 and test_size = 0.16
# 0.018462911772239004 for random_state = 4 and test_size = 0.18
# 0.016902412657008772 for random_state = 4 and test_size = 0.2
# 0.017213189095050346 for random_state = 4 and test_size = 0.22
# 0.017689269477271768 for random_state = 4 and test_size = 0.24
# 0.016942109445149886 for random_state = 4 and test_size = 0.26
# 0.016035513127025135 for random_state = 4 and test_size = 0.28
# 0.010249548144276017 for random_state = 5 and test_size = 0.1
# 0.014362387686517953 for random_state = 5 and test_size = 0.12
# 0.014352692411033355 for random_state = 5 and test_size = 0.14
# 0.015920362057632337 for random_state = 5 and test_size = 0.16
# 0.017331436736954055 for random_state = 5 and test_size = 0.18
# 0.018448393612023103 for random_state = 5 and test_size = 0.2
# 0.017415631983194128 for random_state = 5 and test_size = 0.22
# 0.016987094222843068 for random_state = 5 and test_size = 0.24
# 0.016489696822838875 for random_state = 5 and test_size = 0.26
# 0.016158804987123368 for random_state = 5 and test_size = 0.28
# 0.010664687473974277 for random_state = 6 and test_size = 0.1
# 0.011261848866704798 for random_state = 6 and test_size = 0.12
# 0.01238507772695195 for random_state = 6 and test_size = 0.14
# 0.0112107382458153 for random_state = 6 and test_size = 0.16
# 0.01149604257150082 for random_state = 6 and test_size = 0.18
# 0.011514205535188149 for random_state = 6 and test_size = 0.2
# 0.012785191244324708 for random_state = 6 and test_size = 0.22
# 0.01223734057517421 for random_state = 6 and test_size = 0.24
# 0.013769865433662503 for random_state = 6 and test_size = 0.26
# 0.013089866721494172 for random_state = 6 and test_size = 0.28
# 0.014634271369582078 for random_state = 7 and test_size = 0.1
# 0.014441597908044872 for random_state = 7 and test_size = 0.12
# 0.014524159412771706 for random_state = 7 and test_size = 0.14
# 0.016882423849632722 for random_state = 7 and test_size = 0.16
# 0.016711932940743347 for random_state = 7 and test_size = 0.18
# 0.015103346330381207 for random_state = 7 and test_size = 0.2
# 0.015492977176286726 for random_state = 7 and test_size = 0.22
# 0.014907432319138426 for random_state = 7 and test_size = 0.24
# 0.013954403560252255 for random_state = 7 and test_size = 0.26
# 0.013106039501131126 for random_state = 7 and test_size = 0.28
# 0.015014544617112073 for random_state = 8 and test_size = 0.1
# 0.012849851317898503 for random_state = 8 and test_size = 0.12
# 0.013090172048374862 for random_state = 8 and test_size = 0.14
# 0.011852735026820653 for random_state = 8 and test_size = 0.16
# 0.011671795797274506 for random_state = 8 and test_size = 0.18
# 0.010456755609493806 for random_state = 8 and test_size = 0.2
# 0.010260616880588241 for random_state = 8 and test_size = 0.22
# 0.010415966989525755 for random_state = 8 and test_size = 0.24
# 0.01001206562392145 for random_state = 8 and test_size = 0.26
# 0.010815585987107915 for random_state = 8 and test_size = 0.28
# 0.014941584011371689 for random_state = 9 and test_size = 0.1
# 0.014009231466070424 for random_state = 9 and test_size = 0.12
# 0.014141481422251337 for random_state = 9 and test_size = 0.14
# 0.013277911198544523 for random_state = 9 and test_size = 0.16
# 0.012214522434809538 for random_state = 9 and test_size = 0.18
# 0.01215633634535592 for random_state = 9 and test_size = 0.2
# 0.012216976705279064 for random_state = 9 and test_size = 0.22
# 0.013022017401189408 for random_state = 9 and test_size = 0.24
# 0.013289897888383868 for random_state = 9 and test_size = 0.26
# 0.012698115974331844 for random_state = 9 and test_size = 0.28
# 0.011763869725083826 for random_state = 10 and test_size = 0.1
# 0.013362975534409294 for random_state = 10 and test_size = 0.12
# 0.012473809904071128 for random_state = 10 and test_size = 0.14
# 0.012354060160055481 for random_state = 10 and test_size = 0.16
# 0.014113166846523412 for random_state = 10 and test_size = 0.18
# 0.0140359719445073 for random_state = 10 and test_size = 0.2
# 0.014052330880485676 for random_state = 10 and test_size = 0.22
# 0.013487071656249447 for random_state = 10 and test_size = 0.24
# 0.014289113057152941 for random_state = 10 and test_size = 0.26
# 0.013999582560362532 for random_state = 10 and test_size = 0.28
# 0.0098881791371903 for random_state = 11 and test_size = 0.1
# 0.008678425038764504 for random_state = 11 and test_size = 0.12
# 0.009952406262198666 for random_state = 11 and test_size = 0.14
# 0.00926520334942666 for random_state = 11 and test_size = 0.16
# 0.009602366611191106 for random_state = 11 and test_size = 0.18
# 0.012479255904387494 for random_state = 11 and test_size = 0.2
# 0.012788209476188911 for random_state = 11 and test_size = 0.22
# 0.011897957057673072 for random_state = 11 and test_size = 0.24
# 0.011819267645527627 for random_state = 11 and test_size = 0.26
# 0.01150743922599086 for random_state = 11 and test_size = 0.28
# 0.012212559239482858 for random_state = 12 and test_size = 0.1
# 0.010919974524689869 for random_state = 12 and test_size = 0.12
# 0.009934451884635665 for random_state = 12 and test_size = 0.14
# 0.00891227735812489 for random_state = 12 and test_size = 0.16
# 0.009093945778470303 for random_state = 12 and test_size = 0.18
# 0.010391751607071733 for random_state = 12 and test_size = 0.2
# 0.009831972334553801 for random_state = 12 and test_size = 0.22
# 0.009542533399295885 for random_state = 12 and test_size = 0.24
# 0.012571279960798092 for random_state = 12 and test_size = 0.26
# 0.012548300687839423 for random_state = 12 and test_size = 0.28
# 0.006516302043978892 for random_state = 13 and test_size = 0.1
# 0.009286020686923774 for random_state = 13 and test_size = 0.12
# 0.00917784432032988 for random_state = 13 and test_size = 0.14
# 0.01044230192074415 for random_state = 13 and test_size = 0.16
# 0.010008965882079475 for random_state = 13 and test_size = 0.18
# 0.011542622153826357 for random_state = 13 and test_size = 0.2
# 0.01159060256325217 for random_state = 13 and test_size = 0.22
# 0.010854006818349884 for random_state = 13 and test_size = 0.24
# 0.011576969652892477 for random_state = 13 and test_size = 0.26
# 0.01172073969258959 for random_state = 13 and test_size = 0.28
# 0.010766990454926377 for random_state = 14 and test_size = 0.1
# 0.01213549414477811 for random_state = 14 and test_size = 0.12
# 0.01462350032304835 for random_state = 14 and test_size = 0.14
# 0.014463669122676258 for random_state = 14 and test_size = 0.16
# 0.014024586072640883 for random_state = 14 and test_size = 0.18
# 0.014825943524487151 for random_state = 14 and test_size = 0.2
# 0.014957280584417323 for random_state = 14 and test_size = 0.22
# 0.0139496253137462 for random_state = 14 and test_size = 0.24
# 0.01306199198084394 for random_state = 14 and test_size = 0.26
# 0.012862896323486275 for random_state = 14 and test_size = 0.28
# 0.011949218628842892 for random_state = 15 and test_size = 0.1
# 0.011638205001665758 for random_state = 15 and test_size = 0.12
# 0.010655298849229515 for random_state = 15 and test_size = 0.14
# 0.010688059942662361 for random_state = 15 and test_size = 0.16
# 0.013369229096742947 for random_state = 15 and test_size = 0.18
# 0.015801013759776737 for random_state = 15 and test_size = 0.2
# 0.015142352428161733 for random_state = 15 and test_size = 0.22
# 0.014446242744691607 for random_state = 15 and test_size = 0.24
# 0.013838119523529561 for random_state = 15 and test_size = 0.26
# 0.013451923789690418 for random_state = 15 and test_size = 0.28
# 0.013388430323822005 for random_state = 16 and test_size = 0.1
# 0.01184700979200086 for random_state = 16 and test_size = 0.12
# 0.014258886771850767 for random_state = 16 and test_size = 0.14
# 0.01558701014960773 for random_state = 16 and test_size = 0.16
# 0.015263550675684582 for random_state = 16 and test_size = 0.18
# 0.015497035134887528 for random_state = 16 and test_size = 0.2
# 0.014576223267390909 for random_state = 16 and test_size = 0.22
# 0.014106171851618516 for random_state = 16 and test_size = 0.24
# 0.014706110787443532 for random_state = 16 and test_size = 0.26
# 0.014386370486640676 for random_state = 16 and test_size = 0.28
# 0.012190677715452191 for random_state = 17 and test_size = 0.1
# 0.010473782965763755 for random_state = 17 and test_size = 0.12
# 0.010739312229092678 for random_state = 17 and test_size = 0.14
# 0.010287722643525118 for random_state = 17 and test_size = 0.16
# 0.010518007902732832 for random_state = 17 and test_size = 0.18
# 0.00990233651504752 for random_state = 17 and test_size = 0.2
# 0.009897015044528508 for random_state = 17 and test_size = 0.22
# 0.0106774162704472 for random_state = 17 and test_size = 0.24
# 0.010002606053828952 for random_state = 17 and test_size = 0.26
# 0.009621095087225879 for random_state = 17 and test_size = 0.28
# 0.01919394871486621 for random_state = 18 and test_size = 0.1
# 0.017090188113132253 for random_state = 18 and test_size = 0.12
# 0.015863766174767813 for random_state = 18 and test_size = 0.14
# 0.01442280770010366 for random_state = 18 and test_size = 0.16
# 0.017191005301335213 for random_state = 18 and test_size = 0.18
# 0.018012200637406516 for random_state = 18 and test_size = 0.2
# 0.017246368593404015 for random_state = 18 and test_size = 0.22
# 0.016236413511257253 for random_state = 18 and test_size = 0.24
# 0.016675137554373574 for random_state = 18 and test_size = 0.26
# 0.016285436121978393 for random_state = 18 and test_size = 0.28
# 0.011426731823445647 for random_state = 19 and test_size = 0.1
# 0.010149210152177976 for random_state = 19 and test_size = 0.12
# 0.010277173336085075 for random_state = 19 and test_size = 0.14
# 0.011172156389522118 for random_state = 19 and test_size = 0.16
# 0.010411033504839469 for random_state = 19 and test_size = 0.18
# 0.009830419698486036 for random_state = 19 and test_size = 0.2
# 0.01191066662746199 for random_state = 19 and test_size = 0.22
# 0.012310432792654053 for random_state = 19 and test_size = 0.24
# 0.011786238084406549 for random_state = 19 and test_size = 0.26
# 0.011264303069358706 for random_state = 19 and test_size = 0.28
#
#
# least error is 0.006516302043978892 for random_state = 13 and test_size = 0.1

# %% [markdown]
# creating a function to get best random_state in randomForestclassfier
