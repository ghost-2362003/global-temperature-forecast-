# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("globalWarming.csv")
data
# Out:
#      Unnamed: 0  date  LandAverageTemperature  \
# 0             0  1850                7.900667
# 1             1  1851                8.178583
# 2             2  1852                8.100167
# 3             3  1853                8.041833
# 4             4  1854                8.210500
# ..          ...   ...                     ...
# 161         161  2011                9.516000
# 162         162  2012                9.507333
# 163         163  2013                9.606500
# 164         164  2014                9.570667
# 165         165  2015                9.831000
#
#      LandAverageTemperatureUncertainty  LandMaxTemperature  \
# 0                             0.876417           13.476667
# 1                             0.881917           13.081000
# 2                             0.918250           13.397333
# 3                             0.835000           13.886583
# 4                             0.825667           13.977417
# ...

# %%
plt.scatter(data["date"], data["LandAverageTemperature"], s = 50, c = "red")
plt.xlabel("date")
plt.ylabel("temperature")
plt.show()

# %%
data["LandAverageTemperature"] = (data["LandAverageTemperature"] - data["LandAverageTemperature"].mean())/data["LandAverageTemperature"].std()

# %%
plt.scatter(data["date"], data["LandAverageTemperature"], s = 50, c = "red")
plt.xlabel("date")
plt.ylabel("temperature")
plt.show()

# %%
p10 = np.poly1d(np.polyfit(x = data["date"], y = data["LandAverageTemperature"], deg = 10))
p8 = np.poly1d(np.polyfit(x = data["date"], y = data["LandAverageTemperature"], deg = 15))
# Out:
# C:\Users\shubh\AppData\Local\Temp\ipykernel_12692\963543253.py:1: RankWarning: Polyfit may be poorly conditioned
#   p10 = np.poly1d(np.polyfit(x = data["date"], y = data["LandAverageTemperature"], deg = 10))
# C:\Users\shubh\AppData\Local\Temp\ipykernel_12692\963543253.py:2: RankWarning: Polyfit may be poorly conditioned
#   p8 = np.poly1d(np.polyfit(x = data["date"], y = data["LandAverageTemperature"], deg = 15))

# %%
xp = np.linspace(1850, 2016, 165)

# %%
plt.plot(data['date'], data['LandAverageTemperature'], 'o', xp, p10(xp), '-', xp, p8(xp), '--')

# %%
for i in range(1, 10):
    p = np.poly1d(np.polyfit(x = data["date"], y = data["LandAverageTemperature"], deg = i))
    plt.plot(data['date'], data['LandAverageTemperature'], 'o', data['date'], p(data['date']), '-')
# Out:
# C:\Users\shubh\AppData\Local\Temp\ipykernel_12692\2167501531.py:2: RankWarning: Polyfit may be poorly conditioned
#   p = np.poly1d(np.polyfit(x = data["date"], y = data["LandAverageTemperature"], deg = i))
# C:\Users\shubh\AppData\Local\Temp\ipykernel_12692\2167501531.py:2: RankWarning: Polyfit may be poorly conditioned
#   p = np.poly1d(np.polyfit(x = data["date"], y = data["LandAverageTemperature"], deg = i))
# C:\Users\shubh\AppData\Local\Temp\ipykernel_12692\2167501531.py:2: RankWarning: Polyfit may be poorly conditioned
#   p = np.poly1d(np.polyfit(x = data["date"], y = data["LandAverageTemperature"], deg = i))
